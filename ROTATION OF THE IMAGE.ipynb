# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def main():
    imgpath1="C:\\Users\\user\\Downloads\\opencv\\misc\\house.tiff"
    
    img1=cv2.imread(imgpath1,1)
    img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
    
    rows,columns,channels=img1.shape
    R=cv2.getRotationMatrix2D((columns/2,rows/2),50,0.5)
    
    
    print(R)
    
    
    output=cv2.warpAffine(img1,R,(columns,rows))
    
    plt.imshow(output)
    plt.title('rotated image')
    plt.show()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
if __name__=="__main__":
    main()
# Out:
# [[  0.3213938    0.38302222  75.66949724]
#  [ -0.38302222   0.3213938  271.77687468]]
