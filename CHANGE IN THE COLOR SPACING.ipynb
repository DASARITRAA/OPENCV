# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
def main():
    imgpath="C:\\Users\\user\\Downloads\\opencv\\standard_test_images\\lena_color_512.tif"
    img=cv2.imread(imgpath,1)
    img1=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
   
    plt.imshow(img)
    plt.title('color image BGR')
    plt.xticks([]) and plt.yticks([])
    plt.show()
    
    plt.imshow(img1)
    plt.title('color image RGB')
    plt.xticks([]) and plt.yticks([])
    plt.show()
    
    
if __name__=="__main__":
    main()
